# %%
import pandas as pd

# %%
df = pd.read_csv('D:/Data_Analysis/gdp.csv')
df
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
for col in df.columns:
    print(df[col].nunique(), end = '\t:')
    print(col)
# Out:
# 256	:Country Name
# 256	:Country Code
# 57	:Year
# 11398	:Value

# %%
df_pr = df[df['Country Name'] == 'Arab World']

# %%
data = df_pr.values

for i in range(1, len(data)):
    print(data[i], data[i-1])
# Out:
# ['Arab World' 'ARB' 1969 28434203615.4829] ['Arab World' 'ARB' 1968 25760683041.0857]
# ['Arab World' 'ARB' 1970 31385499664.0672] ['Arab World' 'ARB' 1969 28434203615.4829]
# ['Arab World' 'ARB' 1971 36426909888.3928] ['Arab World' 'ARB' 1970 31385499664.0672]
# ['Arab World' 'ARB' 1972 43316056615.4562] ['Arab World' 'ARB' 1971 36426909888.3928]
# ['Arab World' 'ARB' 1973 55018394945.5825] ['Arab World' 'ARB' 1972 43316056615.4562]
# ['Arab World' 'ARB' 1974 105145803084.377] ['Arab World' 'ARB' 1973 55018394945.5825]
# ['Arab World' 'ARB' 1975 116337021938.341] ['Arab World' 'ARB' 1974 105145803084.377]
# ['Arab World' 'ARB' 1976 144846175400.488] ['Arab World' 'ARB' 1975 116337021938.341]
# ['Arab World' 'ARB' 1977 167308327683.593] ['Arab World' 'ARB' 1976 144846175400.488]
# ['Arab World' 'ARB' 1978 183555544342.189] ['Arab World' 'ARB' 1977 167308327683.593]
# ['Arab World' 'ARB' 1979 248646206367.003] ['Arab World' 'ARB' 1978 183555544342.189]
# ...

# %%
data = df_pr.values

for i in range(1, len(data)):
    
    prev_year = data[i-1][3]
    curr_year = data[i][3]
#     print(data[i][3] - data[i-1][3])
    print(data[i][2], ':', round(((curr_year - prev_year)/prev_year)*100, 2), '%')
# Out:
# 1961 : 5.95 %
# 1962 : 7.47 %
# 1963 : 14.85 %
# 1964 : 16.64 %
# 1965 : 5.44 %
# 1966 : -22.99 %
# 1967 : 9.31 %
# 1968 : 5.89 %
# 1969 : 10.1 %
# 1970 : 6.8 %
# 1971 : 7.9 %
# 1972 : 6.11 %
# 1973 : 19.66 %
# 1974 : 16.38 %
# 1975 : -1.06 %
# 1976 : 4.31 %
# 1977 : 18.27 %
# 1978 : 13.02 %
# 1979 : 11.43 %
# 1980 : 21.79 %
# 1981 : 3.85 %
# 1982 : 3.73 %
# 1983 : 8.74 %
# 1984 : -2.8 %
# 1985 : 9.59 %
# 1986 : 7.09 %
# 1987 : 12.07 %
# 1988 : 6.29 %
# 1989 : -0.18 %
# 1990 : 8.42 %
# 1991 : -15.85 %
# 1992 : 6.7 %
# 1993 : -3.09 %
# 1994 : 17.18 %
# 1995 : 10.09 %
# 1996 : 9.05 %
# 1997 : 5.85 %
# 1998 : 1.32 %
# 1999 : 8.89 %
# 2000 : 2.09 %
# 2001 : 3.64 %
# 2002 : 6.08 %
# 2003 : 18.01 %
# 2004 : 16.69 %
# 2005 : 15.61 %
# 2006 : 13.77 %
# 2007 : 30.51 %
# 2008 : -1.18 %
# 2009 : 11.54 %
# 2010 : 25.13 %
# 2011 : 10.05 %
# 2012 : 0.25 %
# 2013 : 1.59 %
# 2014 : 9.62 %
# 2015 : 2.68 %
# 2016 : 8.32 %

# %%
df_pr = df[df['Country Name'] == 'India']

data = df_pr.values

gdp_change = [0]

for i in range(1, len(data)):
    gdp_change.append(round(((data[i][3] - data[i-1][3]) / data[i-1][3]) * 100, 2))
    
df_pr.assign(GDP = gdp_change)
# Out:
#      Country Name Country Code  Year         Value    GDP
# 6074        India          IND  1960  3.653593e+10   0.00
# 6075        India          IND  1961  3.870910e+10   5.95
# 6076        India          IND  1962  4.159907e+10   7.47
# 6077        India          IND  1963  4.777600e+10  14.85
# 6078        India          IND  1964  5.572687e+10  16.64
# 6079        India          IND  1965  5.876042e+10   5.44
# 6080        India          IND  1966  4.525364e+10 -22.99
# 6081        India          IND  1967  4.946617e+10   9.31
# 6082        India          IND  1968  5.237732e+10   5.89
# 6083        India          IND  1969  5.766833e+10  10.10
# 6084        India          IND  1970  6.158980e+10   6.80
# 6085        India          IND  1971  6.645256e+10   7.90
# 6086        India          IND  1972  7.050991e+10   6.11
# 6087        India          IND  1973  8.437454e+10  19.66
# 6088        India          IND  1974  9.819828e+10  16.38
# ...
